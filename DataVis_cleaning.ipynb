# %% [markdown]
# # Data Visualizeation
#
# The purpose of this notebopok is to learn how to clean and visualize data
#
# Some tools/libraries being used are:
# - **Pandas**
# - **Seaborn**
# - **Matplotlib**
# - **Numpy**
#
# Before Visualizing we should do some cleaning first \
# (i.e.) Removing/imputing NaN values, encoding string values, etc

# %%
import pandas as pd
import regex as re
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.image import thumbnail

# %%
lego_df = pd.read_csv('lego_sets.csv')

# %%
lego_df.head()
# Out:
#   set_id                     name  year      theme     subtheme themeGroup  \
# 0    1-8          Small house set  1970  Minitalia          NaN    Vintage
# 1    2-8         Medium house set  1970  Minitalia          NaN    Vintage
# 2    3-6         Medium house set  1970  Minitalia          NaN    Vintage
# 3    4-4          Large house set  1970  Minitalia          NaN    Vintage
# 4    4-6  Mini House and Vehicles  1970  Samsonite  Model Maker    Vintage
#
#   category  pieces  minifigs  agerange_min  US_retailPrice  \
# 0   Normal    67.0       NaN           NaN             NaN
# 1   Normal   109.0       NaN           NaN             NaN
# 2   Normal   158.0       NaN           NaN             NaN
# 3   Normal   233.0       NaN           NaN             NaN
# 4   Normal     NaN       NaN           NaN             NaN
#
#                      bricksetURL  \
# 0  https://brickset.com/sets/1-8
# 1  https://brickset.com/sets/2-8
# 2  https://brickset.com/sets/3-6
# 3  https://brickset.com/sets/4-4
# 4  https://brickset.com/sets/4-6
#
#                                      thumbnailURL  \
# 0  https://images.brickset.com/sets/small/1-8.jpg
# 1  https://images.brickset.com/sets/small/2-8.jpg
# 2  https://images.brickset.com/sets/small/3-6.jpg
# 3  https://images.brickset.com/sets/small/4-4.jpg
# 4                                             NaN
#
#                                           imageURL
# 0  https://images.brickset.com/sets/images/1-8.jpg
# 1  https://images.brickset.com/sets/images/2-8.jpg
# 2  https://images.brickset.com/sets/images/3-6.jpg
# 3  https://images.brickset.com/sets/images/4-4.jpg
# 4                                              NaN

# %% [markdown]
# ## Describing the dataset
#
# ### 1) Finding duplicate values
#
# Are there any duplicates in the dataset? If so gotta get rid of them\
# They are going to be dropped
#
# ### 2) Find the data types of each column
#
# This will help us figure what data types are in each column so they can be changed or left alone \
# Typically with string values they should be encoded/left alone/dropped
#
# ### 3) Find the Null Values
#
# After handling data types we need to handle and NaN values
# We can either drop or impute, once again it is a case by case situation
#
#
# -----
#
# So now have a look at these tabels
# - DTYPES: Type of data in each column
# - MISSING: What columns have missing values
# - PERCENTAGE MISSING: The percentage missing values in each column

# %%
# find duplicate rows
lego_df[lego_df.duplicated(['name','set_id'], keep=False)]
# there are none
# Out:
# Empty DataFrame
# Columns: [set_id, name, year, theme, subtheme, themeGroup, category, pieces, minifigs, agerange_min, US_retailPrice, bricksetURL, thumbnailURL, imageURL]
# Index: []

# %%
print("Lego data from Data types")
print(lego_df.dtypes)
print("="*28 + "\n")
print("Lego null values sum")
print(lego_df.isnull().sum())
print("="*28 + "\n")
print("Lego missing percentage")
print(lego_df.isnull().sum()/lego_df.isnull().count() * 100)
print("="*28 + "\n")
# Out:
# Lego data from Data types
# set_id             object
# name               object
# year                int64
# theme              object
# subtheme           object
# themeGroup         object
# category           object
# pieces            float64
# minifigs          float64
# agerange_min      float64
# US_retailPrice    float64
# bricksetURL        object
# thumbnailURL       object
# imageURL           object
# dtype: object
# ============================
#
# Lego null values sum
# set_id                0
# name                  0
# year                  0
# theme                 0
# subtheme           3556
# themeGroup            2
# category              0
# pieces             3924
# minifigs          10058
# agerange_min      11670
# US_retailPrice    11475
# bricksetURL           0
# thumbnailURL       1006
# imageURL           1006
# dtype: int64
# ============================
#
# Lego missing percentage
# set_id             0.000000
# name               0.000000
# year               0.000000
# theme              0.000000
# subtheme          19.266403
# themeGroup         0.010836
# category           0.000000
# pieces            21.260226
# minifigs          54.494230
# agerange_min      63.228044
# US_retailPrice    62.171534
# bricksetURL        0.000000
# thumbnailURL       5.450507
# imageURL           5.450507
# dtype: float64
# ============================

# %% [markdown]
# After looking there are some things to note: \
# Starting with dtypes:
# | Column | dtype |
# | ----------- | ----------- |
# | set_id | object |
# | name | object |
# | theme | object |
# | subtheme | object |
# | themeGroup | object |
# | category | object |
# | bricksetURL  | object |
# | thumbnailURL | object |
# | imageURL | object |
#
# From the looks of it most of the data in this set are object data types\
#
# Also two columns come out with > 20% in missing values and those are: **pieces**(21.26%), **minifigs**(54.46%), **agerange_min**(63.22%), and **US_retailPrice**(62.17%)
#
# These can definitely be webscrapped, for that a webscapper is will be necessary but that will be handled later \
# NOTE: The subtheme columns has 19% missing values, we can just drop the rows with that those missing values
#
# So
# 1) Save URLs for webscrapping
# 2) Drop the columns that aren't theme, subtheme and category
# 3) Drop rows with missing subtheme values
# 3) Convert float64 to int64
# 3) Take a look at the unique values of theme, subtheme, and category

# %%
# 1)
# save the URLs to a df
lego_df_urls = lego_df[["bricksetURL", "imageURL", "thumbnailURL", "set_id"]]
print(lego_df_urls.head())

# 2)
# drop all columns of dtype obj that isn't in this list
cols_to_keep = ["theme", "subtheme", "category", "set_id"]   # spelling must match your frame
lego_df = lego_df.drop(
    columns=[c for c in lego_df.select_dtypes("object").columns
             if c not in cols_to_keep]
)
# 3)
# drop the rows with NaN subtheme values
lego_df = (
    lego_df                # start with current frame
      .dropna(subset=["subtheme"])                 # 1) remove NaN in subtheme
      .loc[lambda d: d["subtheme"].str.strip() != ""]   # 2) remove empty strings
)

# 4)
# convert float64 to int64
int_cols = ["year", "pieces", "minifigs"]
lego_df[int_cols] = lego_df[int_cols].astype("Int64")
# Out:
#                      bricksetURL  \
# 0  https://brickset.com/sets/1-8
# 1  https://brickset.com/sets/2-8
# 2  https://brickset.com/sets/3-6
# 3  https://brickset.com/sets/4-4
# 4  https://brickset.com/sets/4-6
#
#                                           imageURL  \
# 0  https://images.brickset.com/sets/images/1-8.jpg
# 1  https://images.brickset.com/sets/images/2-8.jpg
# 2  https://images.brickset.com/sets/images/3-6.jpg
# 3  https://images.brickset.com/sets/images/4-4.jpg
# 4                                              NaN
#
#                                      thumbnailURL set_id
# 0  https://images.brickset.com/sets/small/1-8.jpg    1-8
# 1  https://images.brickset.com/sets/small/2-8.jpg    2-8
# 2  https://images.brickset.com/sets/small/3-6.jpg    3-6
# 3  https://images.brickset.com/sets/small/4-4.jpg    4-4
# 4                                             NaN    4-6

# %%
# 4) look at unique values and counts
print("Lego null values sum")
print(lego_df.isnull().sum())
print("="*28 + "\n")
print("Lego missing percentage")
print(lego_df.isnull().sum()/lego_df.isnull().count() * 100)
print("="*28 + "\n")
# Out:
# Lego null values sum
# set_id               0
# year                 0
# theme                0
# subtheme             0
# category             0
# pieces            3785
# minifigs          7991
# agerange_min      9004
# US_retailPrice    8834
# dtype: int64
# ============================
#
# Lego missing percentage
# set_id             0.000000
# year               0.000000
# theme              0.000000
# subtheme           0.000000
# category           0.000000
# pieces            25.400980
# minifigs          53.627273
# agerange_min      60.425475
# US_retailPrice    59.284612
# dtype: float64
# ============================

# %% [markdown]
# Now we take a look at the unique values and the number of unique values

# %%
print("Theme unique values")
print(lego_df["theme"].unique())
print(lego_df["theme"].nunique())
print("="*50 + "\n")
print("Subtheme unique values")
print(lego_df["subtheme"].unique())
print(lego_df["subtheme"].nunique())
print("="*50 + "\n")
print("Category unique values")
print(lego_df["category"].unique())
print(lego_df["category"].nunique())
# Out:
# Theme unique values
# ['Samsonite' 'Trains' 'Books' 'LEGOLAND' 'Duplo' 'Universal Building Set'
#  'System' 'Gear' 'Basic' 'Dacta' 'Technic' 'Service Packs' 'Promotional'
#  'Town' 'Castle' 'Space' 'Scala' 'Pirates' 'Assorted' 'Creator' 'Aquazone'
#  'Western' 'Education' 'Time Cruisers' 'Adventurers' 'Mindstorms'
#  'Seasonal' 'Rock Raiders' 'Belville' 'Star Wars' 'Baby' 'Sports'
#  'Advanced models' 'Bulk Bricks' 'Racers' 'Studios' 'Bionicle'
#  'Harry Potter' 'Explore' 'Alpha Team' 'Miscellaneous' 'World City'
#  'Island Xtreme Stunts' '4 Juniors' 'Spider-Man' 'Clikits' 'City' 'Batman'
#  'Exo-Force' 'Factory' 'Make and Create' 'Indiana Jones' 'Power Functions'
#  'Architecture' 'Bricks and More' 'Games' 'Power Miners' 'HERO Factory'
#  'Prince of Persia' 'Toy Story' 'Collectable Minifigures' 'Atlantis'
#  'Ninjago' 'Pirates of the Caribbean' 'Cars' 'Ideas' "Pharaoh's Quest"
#  'DC Comics Super Heroes' 'Friends' 'Marvel Super Heroes'
#  'The Lord of the Rings' 'Monster Fighters' 'The Hobbit'
#  'Teenage Mutant Ninja Turtles' 'Creator Expert' 'Legends of Chima'
#  'Minecraft' 'The Lone Ranger' 'Juniors' 'Disney' 'The LEGO Movie'
#  'Mixels' 'Classic' 'Elves' 'Jurassic World' 'Dimensions'
#  'Speed Champions' 'Scooby-Doo' 'Nexo Knights' 'BrickHeadz' 'Ghostbusters'
#  'DC Super Hero Girls' 'The LEGO Ninjago Movie' 'The LEGO Batman Movie'
#  'Unikitty' 'Overwatch' 'The LEGO Movie 2' 'Hidden Side' 'Bricklink'
#  'Stranger Things' 'Icons' 'Monkie Kid' 'Super Mario' 'Trolls World Tour'
#  'Dots' 'Art' 'Brick Sketches' 'Minions: The Rise of Gru' 'Vidiyo'
#  'Promotional ' 'Collectable minifigures' 'Avatar']
# 112
# ==================================================
#
# Subtheme unique values
# ['Model Maker' 'Supplemental' 'Supplemental / 4.5V' '4.5v' 'LEGO'
#  'Vehicle' 'Building' 'Basic Set' 'Supplemental / 12V' '12V' 'Gears'
#  'Promotional' 'Basic set' '4.5V' 'Storage' '4.5/12V' 'Jumbo Bricks'
#  'Town' 'Large Vehicle' 'Boats' 'Supplementaries' 'Model'
#  'Supplementary Set' 'Seasonal' 'Supplementary' 'Trains' 'Ferries'
#  'Accessories' 'Classic' 'Technic' 'Special' 'Bags' 'Minifigure Pack'
#  'Jewellery' 'Educational' 'Shops and Services' 'Medical' 'Racing'
#  'Vehicles' 'Maintenance' 'Construction' 'Fire' 'Key Chains/Promotional'
#  'Leisure' 'Police' 'Space' 'Postal' 'Universal' 'Bonus/Value Pack' 'Baby'
#  'Product Collection' 'Lion Knights' 'Black Falcons'
#  'Universal Building Set' 'Flight' 'Emergency' 'Arctic' 'Duplo'
#  'Forestmen' 'Futuron' 'Blacktron' 'Brick Kicks' 'Harry N. Abrams Inc.'
#  'Black Knights' 'Miscellaneous' 'Furniture' 'Farm' 'Monorail' 'Castle'
#  'Imperial Guards' 'Coastguard' 'Rescue' 'Space Police' 'LEGO PreSchool'
#  'Pirates' 'M-Tron' 'Blacktron 2' '9V' 'Toolo' 'Wolfpack' 'Paradisa'
#  'Space Police 2' 'System' 'LEGO brand store opening set' 'Dragon Knights'
#  'Ice Planet 2002' 'Software' 'Trading Cards' 'Islanders' 'Spyrius'
#  'Unitron' 'Key Chains/Space' 'Mania Magazine' 'Aquanauts' 'Primo'
#  'Belville' 'Aquazone' 'Royal Knights' 'Aquasharks' 'Launch Command'
#  'Clothing' 'Exploriens' 'Bonus/Value pack' 'Dark Forest'
#  'Imperial Armada' 'Cowboys' 'UFO' 'Divers' 'RoboForce' 'Aquaraiders'
#  'Indians' 'Fright Knights' 'Dolls' 'Western' 'Video Games/PC' 'Outback'
#  'Time Twisters' 'City' 'Digital media' 'Education' 'Extreme Team'
#  'Desert' 'Insectoids' 'Competition' 'Res-Q' 'Ninja' 'Football'
#  'Key Chains/Castle' 'Adventurers' 'Scala' 'Hydronauts' 'Stingrays' 'Race'
#  'Microtechnic' '1.0' 'Product collection' 'Klutz' 'Slizer' 'Christmas'
#  'Space Port' 'Shell' 'Jungle' 'Little Forest Friends' 'Winnie the Pooh'
#  'Key Chains/Star Wars' 'Video Games/Nintendo 64' 'Video Games/PS'
#  'Fairy-Tale' 'Episode I' 'Episode IV' 'Episode VI' 'Episode V' '1.5'
#  'Star Wars' 'Dorling Kindersley' 'Watches/Clocks' 'Telekom' 'Easter'
#  'Dino Island' "Knights' Kingdom I" 'Robo Riders' 'Pens'
#  "Disney's Baby Mickey" 'Minifig Pack' 'Mosaic' 'Landmarks' 'Sculptures'
#  'Key Chains/Town' 'Key Chains/Rock Raiders' 'Key Chains/Seasonal'
#  'Key Chains/Adventurers' 'Video Games/Game Boy Color'
#  'Ultimate Collector Series' 'Speed Slammers' 'Soft bricks' 'Studios'
#  'FIRST LEGO League Challenge' 'Mindstorms' 'Housewares' 'Life On Mars'
#  'Xalax' 'Stunts' 'Jurassic Park III' 'Matoran' 'Zooters'
#  'Bob the Builder' 'Aircraft' '2.0' 'Key Chains/Brick'
#  'Key Chains/Studios' 'Key Chains/Island Xtreme Stunts'
#  'Key Chains/Western' 'Bucket' "Philosopher's Stone"
#  'Video Games/Game Boy Advance' 'Video Games/PS2' 'Toa Mata' 'Rahi'
#  'Turaga' 'Trading/Playing cards' 'Stationery' 'No Starch Press'
#  'LEGOLAND' 'Spider-Man' 'Horror' 'Imagination' 'Mission Deep Sea' 'Logic'
#  'Together' 'Being Me' 'My Own Creation' 'Key Chains/Life On Mars'
#  'Minifigure' 'Key Chains/Racers' 'Key Chains/Sports' 'Key Chains/Pirates'
#  'Drome Racers' 'Chamber of Secrets' 'Photo frames' 'Episode II'
#  'Williams F1' 'Bohrok Va' 'Warriors' 'Bohrok' 'Toa Nuva' 'Explore'
#  'General' 'Mini Building Set' 'Designer Set' 'Orient Expedition'
#  'Gravity Games' 'Basketball' 'Hockey' 'Inventor Set' 'Original Film'
#  'Police and Rescue' 'Little Robots' 'Plush' 'Bohrok-Kal' 'Rahkshi'
#  'Thanksgiving' 'Video Games/Gamecube' 'Video Games/Xbox'
#  'Key Chains/Orient Expedition' 'Magnets/Bricks' 'Key Chains/Bionicle'
#  'Glued models' '3 in 1' 'Key Chains/Miscellaneous' 'LEGO Ville' 'Ferrari'
#  'Prisoner of Azkaban' 'Mission Deep Freeze' 'Spider-Man 2'
#  'Dora the Explorer' 'Outdoor RC' 'Toa Metru' 'Vahki'
#  "Knights' Kingdom II" 'Legends' 'Maersk' 'Key Chains/World City'
#  'LEGO brand stores' 'Key Chains/Clikits' 'Key Chains/Harry Potter'
#  'Role-play toys' 'Key Chains/Spider Man' 'Goblet of Fire' 'Airport'
#  'Bulk Set' 'Princess Castle' 'Rahaga' 'Thomas the Tank Engine'
#  'Episode III' 'Harbor' 'Road Plates' 'Tiny Turbos' 'Power Racers'
#  'Toa Hordika' 'Visorak' 'Playsets' 'Toa Hagah' 'Board Games' 'Bedding'
#  'LEGO Inside Tour Exclusive' '6 in 1' '8 in 1' 'Original'
#  'Fast food toys' 'Zoo' 'NXT' 'Toa Inika' 'Piraka' 'Lights'
#  'Key Chains/Exo-Force' 'Key Chains/City' 'Key Chains/Animal'
#  "Magnets/Knights' Kingdom" 'Magnets/Star Wars' 'Magnets/Minifigures'
#  'Key Chains/Vikings' 'Magnets/Batman' 'Magnets/Football'
#  'Magnets/Seasonal' 'Magnets/City' 'Magnets/SpongeBob SquarePants'
#  'Video Games/DS' 'Video Games/PSP' 'Video Games/Xbox 360' 'Golden City'
#  'Beach' 'Order of the Phoenix' 'Fantasy Era' 'Fairytales' 'Mars Mission'
#  'Traffic' 'Toa Mahri' 'Barraki' 'Hydruka' 'Modular Buildings Collection'
#  'Key Chains/Batman' 'Magnets/Exo-Force'
#  'Key Chains/SpongeBob SquarePants' 'Magnets/Castle' 'Bag Charms'
#  'Video Games/Wii' 'Video Games/PS3' 'Employee gift' 'Great Outdoors'
#  'Coast Guard' 'Vestas' 'Dino' 'Last Crusade' 'Raiders of the Lost Ark'
#  'Kingdom of the Crystal Skull' 'Original Content' 'The Clone Wars'
#  'Cargo' 'Deep Jungle' 'Speed Racer' 'Phantoka' 'Mistika'
#  'Battle Vehicles' 'Vehicles/Creatures' 'Custom Cars' 'Brickstructures'
#  'Landmark Series' 'Key Chains/Indiana Jones' 'Battle Pack'
#  'Minifigure collection' 'Magazines/BrickJournal' 'Heel-Verlag'
#  'Fantasia Verlag GmbH' 'Monthly Mini Model Build' 'Minotaurus' 'Ramses'
#  'Creationary' 'Space Police 3' 'Temple of Doom' 'Air Show' 'Lamborghini'
#  'Remote Control' 'NXT 2.0' 'Agori' 'Glatorian' 'Glatorian Legends'
#  'Fairground Collection' 'Winter Village Collection' 'Architect Series'
#  'Magnets/Indiana Jones' 'Key Chains/Power Miners' 'Magnets/Pirates'
#  'General Mills' 'Muji' 'Licensed' 'Half-Blood Prince' 'Holiday'
#  'Toy Story' 'Cars' 'Stars' 'Rise of the Rookies' 'The Sands of Time'
#  'Buildable Figures' 'Toy Story 2' 'Toy Story 3' 'Kingdoms' 'Series 1'
#  'Series 2' "Valentine's Day" 'Halloween' 'Key Chains/Atlantis'
#  'Magnets/Atlantis' 'Key Chains/Toy Story' 'Key Chains/Rock Band'
#  'Key Chains/Prince of Persia' 'Magnets/Prince of Persia'
#  'Magnets/Toy Story' 'Sports' 'Magnets/Harry Potter' 'Key Chains'
#  'Magnets/Miscellaneous' 'Magnets/Bricktober' 'Target' 'Cube Dudes'
#  'John Wiley & Sons' 'Conway' 'Toys R Us' 'Ordeal of Fire' 'Spinners'
#  'Savage Planet' 'Pilot Season' 'Heroica' 'The Curse of the Black Pearl'
#  "Dead Man's Chest" 'On Stranger Tides' 'Deathly Hallows' 'Alien Conquest'
#  'Cars 2' 'Series 3' 'Series 4' 'Series 5' 'Key Chains/Locations'
#  'Key Chains/Ninjago' 'Magnets/Ninjago' 'Booster Pack'
#  "Key Chains/Pharaoh's Quest" "Magnets/Pharaoh's Quest"
#  'Key Chains/Pirates of the Caribbean' 'Magnets/Pirates of the Caribbean'
#  'Video Games/3DS' 'LEGO internal' 'The Dark Knight Trilogy'
#  'CreateSpace/Bartneck' 'Heartlake City' 'Tree Houses' 'Horseback Riding'
#  'Houses' 'Baking' 'Summer' 'Music' 'Science' 'Pets' 'Art' 'Bedrooms'
#  'Mining' 'Forest Police' 'Great Vehicles' 'Forest Fire' 'Disney Princess'
#  'Breakout' 'Batman' 'Superman' 'The Avengers' 'X-Men'
#  'Ultimate Spider-Man' 'Series 6' 'Series 7' 'Series 8' 'Team GB'
#  'Rise of the Snakes' 'The Fellowship of the Ring'
#  'The Return of the King' 'The Two Towers' 'The Old Republic'
#  'Booster pack' 'Planet Set' 'Gift with Purchase' 'Mickey'
#  'An Unexpected Journey' 'Birthday' 'Combi-pack'
#  'Key Chains/Monster Fighters' 'Key Chains/LEGOLAND' 'Magnets/LEGOLAND'
#  'Key Chains/Super Heroes' 'Magnets/Super Heroes'
#  'Key Chains/Lord Of The Rings' 'Magnets/Lord Of The Rings'
#  'Key Chains/Marvel Super Heroes' 'Playmats'
#  'Key Chains/DC Comics Super Heroes' 'Posters' 'Video Games/PS Vita'
#  'Henry Holt & Company' 'CreateSpace' 'Remember When'
#  'Chinese Traditional Festivals' 'Circus' 'Planes'
#  'Jake and the Never Land Pirates' 'Book Parts' 'Micro World' 'Iron Man 3'
#  'The Desolation of Smaug' 'Galaxy Squad' 'The Power of the CHI'
#  'TV Series' 'EV3' 'Spring' 'Fall' 'Animals series 1' 'Animals series 2'
#  'Animals series 3' 'Brain Attack' 'Speedorz' 'The Final Battle'
#  'Series 9' 'Series 10' 'Series 11' 'DC Extended Universe' 'Magazine gift'
#  'Key Chains/Legends of Chima' 'Key Chains/Teenage Mutant Ninja Turtles '
#  'Key Chains/The Lone Ranger' 'Bag charms' 'Stickers' 'FIRST LEGO League'
#  'Games' 'Video Games/Wii U' 'Phone cases' 'Square Fish'
#  "Barron's Educational Series" 'Skyhorse Publishing' 'Mitchell Beazley'
#  'Random House' 'Loose Build' 'Mickey Mouse Clubhouse'
#  'Marvel Super Heroes' 'Fantasy' 'Teenage Mutant Ninja Turtles'
#  'DC Comics Super Heroes' 'Girl' 'NASA' 'Minifig-scale' 'Jungle Rescue'
#  'Tangled' 'Outlands' 'Fire vs. Ice' 'Invasion From Below' 'Park'
#  'Animals series 4' 'Animals series 5' 'Animals series 6'
#  'The Little Mermaid' 'Brave' 'Cinderella' 'Legend Beasts' 'Rebooted'
#  '2 in 1' 'The LEGO Movie' 'The Simpsons' 'Series 12' 'Microfighters'
#  'Rebels' 'Avengers Assemble' 'Guardians of the Galaxy'
#  'The Battle of the Five Armies' 'Movie' 'Key Chains/The LEGO Movie'
#  'Role-Play toys' 'Key Chains/Friends' 'Billund stores' 'Justice League'
#  'Video Games/PS4' 'Video Games/Xbox One' 'Watches/Clocks '
#  'Magazines/Blocks' 'Arvo Brothers' 'Forest Animals' 'Sofia the First'
#  'Doc McStuffins' 'Creative Building' 'Creative Box' 'Baseplates'
#  'Pop Star' 'The Force Awakens' 'Tournament of Elements' 'Possession'
#  'Avengers: Age of Ultron' 'Swamp Police' 'Sleeping Beauty' 'Aladdin'
#  'Frozen' 'Vet' 'Deep Sea Explorers' 'Tribe Packs' 'Airjitzu' 'Protectors'
#  'Toa Masters' 'Skull Army' 'Series 13' 'The Simpsons Series 2'
#  'Series 14 - Monsters' 'Starter Pack' 'Level Pack' 'Team Pack' 'Fun Pack'
#  'Battlefront' 'McLaren' 'Porsche' 'Ant-Man' 'Magazine Gift'
#  'Role-Play Toys' 'Key chains/Star Wars' 'WeDo' 'Pick A Model'
#  'Employee Gift' 'Captain America: The Winter Soldier' 'Digital Media'
#  'Krause Publications' 'LOM Art' 'Ninjago' 'Friends'
#  'Miles from Tomorrowland' 'Minnie' 'Skylines' 'Prison Island'
#  'Volcano Explorers' 'Adventure Camp' 'Amusement Park' 'Skybound'
#  'Captain America: Civil War' 'Uniqlo' 'Beauty and the Beast'
#  'Palace Pets' 'Party' 'FIRST LEGO League Explore' 'Season 1' 'Season 2'
#  'Ultimate' 'Day of the Departed' 'Series 15' 'Disney' 'Series 16'
#  'DFB Series' 'Disney Parks' 'Story Pack' 'Elemental Creatures'
#  'Toa Uniters' 'Shadow Horde' 'MicroFighters' 'Rogue One' 'Reboot'
#  'Chevrolet' 'Ford' 'Audi' 'Batman Classic TV Series' 'Doctor Strange'
#  'Mighty Micros' 'Battle Packs' 'Key Chains/Nexo Knights'
#  'Key Chains/Elves' 'Magnets/Locations' 'Video Games/XBOX One'
#  'The History Press' 'McGraw Hill' 'Page Street Publishing' 'Quarry'
#  'Weldon Owen' 'Thunder Bay Press' 'Graphic Arts Books' 'Dpunkd'
#  'LEGO Brand Store Opening Set' 'Cars 3' 'Mickey and the Roadster Racers'
#  'Snow Resort' 'The Hands of Time' 'Guardians of the Galaxy Vol. 2'
#  'The Last Jedi' 'LEGO House' 'Moana' 'Dog Show' 'The LEGO Ninjago Movie'
#  'Season 3' 'Season 4' 'Battle Suits' 'Combo NEXO Powers'
#  'Spinjitzu Masters' 'The LEGO Batman Movie' 'Series 17'
#  'Dead Men Tell No Tales' 'Mercedes' 'Bugatti' 'Avengers'
#  'Spider-Man: Homecoming' 'Thor: Ragnarok'
#  'Key Chains/The LEGO Batman Movie' 'Key Chains/The LEGO Ninjago Movie'
#  'Key Chains/LEGO House' 'Video Games/Nintendo Switch' 'Motorbooks'
#  'Scholastic' 'Spiderwize' 'Glenat' 'Building Bigger Thinking' 'Bricks'
#  'Jurassic World: Fallen Kingdom' 'Incredibles 2'
#  'Marvel Super Hero Adventures' 'Jurassic World' 'Mountain Police' 'Solo'
#  'Fallen Kingdom' 'Black Panther' 'Make It Yours' 'Avengers: Infinity War'
#  'Sons of Garmadon' 'Hunted' 'Mulan' 'Tangled: The Series' 'Go Brick Me'
#  'Back to the Future' 'Minecraft' 'Wizarding World' 'Ghostbusters'
#  'Blind Bags Series 1' 'FIRST LEGO League Discover' 'Dragon Masters'
#  'The LEGO Batman Movie Series 2' 'Series 18' 'Harry Potter' 'Season 5'
#  'Master Builder Series' 'Jurassic Park' 'Fantastic Beasts'
#  'Ant-Man and the Wasp' 'Key Chains/Disney' 'Key Chains/Minifigures'
#  'Key Chains/Minecraft' '60 Years of the LEGO Brick' 'Minifigure frames'
#  'Magazines/Brick Fanatics' 'Lonely Planet Kids' 'Toy Story 4'
#  'The LEGO Movie 2' 'Creative Fun' 'BigFig Series 1' 'Sky Police'
#  'Mars Exploration' 'Avengers: Endgame' 'Frozen II'
#  'Secrets of the Forbidden Spinjitzu' 'Spider-Man: Far From Home'
#  'Photo Frames' 'Batman 1989' 'Heart Box' 'Rescue Mission' 'Spinjitzu'
#  'Spinjitzu Slam' 'Disney Series 2' 'Disney series 2' 'Series 19'
#  'Resistance' 'The Rise of Skywalker' 'Boost' 'The Mandalorian' 'Dodge'
#  'Mini' 'Legend of Isla Nublar' 'Captain Marvel' 'March of the Oni'
#  'Key Chains/The LEGO Movie 2' 'Wooden Originals' 'SPIKE' 'LEGO Internal'
#  'Clip' 'AFOL Designer Program' 'Stadiums' 'Creative Bricks'
#  'BigFig Series 2' 'A Hero is Born' 'Expansion Set' 'Prime Empire'
#  'Monkie Kid' 'Wedding' 'Universal Monsters' 'Play Cube' 'Bracelets'
#  'Extra Dots' 'Storybook Adventures' 'Elite Police' 'Spinjitzu Burst'
#  'DC Super Heroes' 'Series 20' 'Harry Potter Series 2' 'Starter Course'
#  'Character Pack - Series 1' 'Power-Up Pack' 'Arcade Pod'
#  'Master of the Mountain' 'Helmet Collection' "Galaxy's Edge"
#  'Black Widow' 'Iron Man' 'Nissan' 'Jaguar' 'Key Chains/Trolls World Tour'
#  'Bag Tags' 'LEGO Brand Stores' 'Chronicle' 'Jigsaw'
#  'Botanical Collection' 'Adidas' 'Mickey and Friends'
#  'Spidey and His Amazing Friends'
#  'Shang-Chi and the Legend of the Ten Rings' 'The Island'
#  'Raya and the Last Dragon' 'Wildlife Rescue' 'Minions: The Rise of Gru'
#  'VIP Add On Pack' 'play Cube' 'Forest' 'Bag Tag' 'Lots of Dots'
#  'Bandmates - Series 1' 'BeatBox' 'Bandmates - Series 2' 'Stages'
#  'Encanto' 'BricQ' 'Stuntz' 'Marvel Studios' 'Series 21' 'Looney Tunes'
#  'Maker Set' 'Character Pack - Series 2' 'Character Pack - Series 3'
#  'Epic Battle Set' 'Seabound' 'The Bad Batch' 'Eternals'
#  'Spider-Man: No Way Home' 'What If...?' 'Hogwarts Moments' 'Koenigsegg'
#  'Toyota' ' Camp Cretaceous' 'Key Chains/Minions: The Rise of Gru'
#  'Key Chains/Monkie Kid' 'Key Chains/Friends (TV series)'
#  'Key Chains/Sesame Street' '2021 Designer Program' 'Key Chains/Dots'
#  'Collectable Coin' 'Clothing / Adidas' 'Tin Signs'
#  'Key Chains/Super Mario' 'Calendars' 'Buster Books' 'Castle System'
#  'Space System' 'Lightyear' 'Spidey and his Amazing Friends'
#  '90 Years of Play' 'Dominion' 'Aston Martin' 'The Batman' 'Core'
#  'Postcard' 'Stranger Things' 'Avatar' 'Bracelet & Bag Tag' 'Patches'
#  'Missions' 'Series 22' 'Series 24' 'Spinjitzu Ninja Training'
#  'The Muppets' ' The Muppets' 'Series 23' 'Character Pack - Series 4'
#  'Character Pack - Series 5' 'Crystalized' 'The Book of Boba Fett'
#  'Diorama Collection' 'Obi-Wan Kenobi' 'Jedi: Fallen Order' 'Andor'
#  'Doctor Strange in the Multiverse of Madness' 'Thor: Love and Thunder'
#  'Black Panther: Wakanda Forever' 'Iron Man 2' 'Lotus' 'Overwatch 2'
#  'Key Chains/Looney Tunes' 'Key Chains/Stranger Things' 'Key Chains/DC'
#  'Magnets' 'Video Games/Xbox Series XS & Xbox One' 'Puzzle' 'DOTS'
#  'Video Games/PS5' 'VIP Reward' 'Murdoch Books']
# 895
# ==================================================
#
# Category unique values
# ['Normal' 'Book' 'Other' 'Gear' 'Collection' 'Extended' 'Random']
# 7

# %% [markdown]
# ### Filling null values
#
# As seen, the last columns have quite a few missing values \
# Sometimes they can be filled in with medians, means, etc, but we are going to try to actually find them with a webscrapper
#
# Im sure the data for pieces, minifigs, and the price can be found, the ones that cannot will be filled in

# %%
needs_fill = lego_df.loc[
    lego_df["pieces"].isna() |
    lego_df["minifigs"].isna() |
    lego_df["US_retailPrice"].isna(),
    ["set_id"]                              # Brickset & Rebrickable key
].drop_duplicates()


needs_fill.head()
# Out:
#   set_id
# 4    4-6
# 5  078-1
# 6  104-1
# 7  126-1
# 8  157-3

# %%
lego_df_urls.to_csv("lego_urls_setIDs.csv", index=True)
